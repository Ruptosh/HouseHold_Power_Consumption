# %% [markdown]
# # Household Power Consumption

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\rupto\Downloads\iNeuron\Data\household_power_consumption.txt', sep = ";", low_memory='False',na_values=['nan','?'] )

# %%
df
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 0        16/12/2006  17:24:00                4.216                  0.418
# 1        16/12/2006  17:25:00                5.360                  0.436
# 2        16/12/2006  17:26:00                5.374                  0.498
# 3        16/12/2006  17:27:00                5.388                  0.502
# 4        16/12/2006  17:28:00                3.666                  0.528
# ...             ...       ...                  ...                    ...
# 2075254  26/11/2010  20:58:00                0.946                  0.000
# 2075255  26/11/2010  20:59:00                0.944                  0.000
# 2075256  26/11/2010  21:00:00                0.938                  0.000
# 2075257  26/11/2010  21:01:00                0.934                  0.000
# 2075258  26/11/2010  21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
df.head()
# Out:
#          Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00                4.216                  0.418   234.84
# 1  16/12/2006  17:25:00                5.360                  0.436   233.63
# 2  16/12/2006  17:26:00                5.374                  0.498   233.29
# 3  16/12/2006  17:27:00                5.388                  0.502   233.74
# 4  16/12/2006  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0

# %%
df.tail()
# Out:
#                Date      Time  Global_active_power  Global_reactive_power  \
# 2075254  26/11/2010  20:58:00                0.946                    0.0
# 2075255  26/11/2010  20:59:00                0.944                    0.0
# 2075256  26/11/2010  21:00:00                0.938                    0.0
# 2075257  26/11/2010  21:01:00                0.934                    0.0
# 2075258  26/11/2010  21:02:00                0.932                    0.0
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 2075254   240.43               4.0             0.0             0.0
# 2075255   240.00               4.0             0.0             0.0
# 2075256   239.82               3.8             0.0             0.0
# 2075257   239.70               3.8             0.0             0.0
# 2075258   239.55               3.8             0.0             0.0
#
#          Sub_metering_3
# 2075254             0.0
# 2075255             0.0
# 2075256             0.0
# ...

# %%
df.shape
# Out:
# (2075259, 9)

# %%
df.describe().T
# Out:
#                            count        mean       std      min      25%  \
# Global_active_power    2049280.0    1.091615  1.057294    0.076    0.308
# Global_reactive_power  2049280.0    0.123714  0.112722    0.000    0.048
# Voltage                2049280.0  240.839858  3.239987  223.200  238.990
# Global_intensity       2049280.0    4.627759  4.444396    0.200    1.400
# Sub_metering_1         2049280.0    1.121923  6.153031    0.000    0.000
# Sub_metering_2         2049280.0    1.298520  5.822026    0.000    0.000
# Sub_metering_3         2049280.0    6.458447  8.437154    0.000    0.000
#
#                            50%      75%      max
# Global_active_power      0.602    1.528   11.122
# Global_reactive_power    0.100    0.194    1.390
# Voltage                241.010  242.890  254.150
# Global_intensity         2.600    6.400   48.400
# Sub_metering_1           0.000    0.000   88.000
# Sub_metering_2           0.000    1.000   80.000
# ...

# %% [markdown]
# # Taking sample

# %%
df_sample = df.sample(50000).reset_index().drop('index', axis=1)

# %%
df_sample.shape
# Out:
# (50000, 9)

# %%
df_sample.describe().T
# Out:
#                          count        mean       std      min      25%  \
# Global_active_power    49349.0    1.096892  1.061431    0.076    0.308
# Global_reactive_power  49349.0    0.123556  0.112643    0.000    0.048
# Voltage                49349.0  240.827253  3.248534  224.320  238.970
# Global_intensity       49349.0    4.650887  4.463535    0.200    1.400
# Sub_metering_1         49349.0    1.109567  6.083683    0.000    0.000
# Sub_metering_2         49349.0    1.289874  5.843395    0.000    0.000
# Sub_metering_3         49349.0    6.475390  8.437584    0.000    0.000
#
#                           50%      75%      max
# Global_active_power      0.61    1.532    9.922
# Global_reactive_power    0.10    0.192    1.192
# Voltage                241.00  242.890  253.090
# Global_intensity         2.60    6.400   43.200
# Sub_metering_1           0.00    0.000   78.000
# Sub_metering_2           0.00    1.000   79.000
# Sub_metering_3           1.00   17.000   31.000

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   50000 non-null  object
#  1   Time                   50000 non-null  object
#  2   Global_active_power    49349 non-null  float64
#  3   Global_reactive_power  49349 non-null  float64
#  4   Voltage                49349 non-null  float64
#  5   Global_intensity       49349 non-null  float64
#  6   Sub_metering_1         49349 non-null  float64
#  7   Sub_metering_2         49349 non-null  float64
#  8   Sub_metering_3         49349 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 3.4+ MB

# %%
# Converting Date into date time format
df_sample['Date'] = pd.to_datetime(df_sample['Date'])

# %%
df_sample.drop('Time', axis=1, inplace=True)

# %%
df_sample.head()
# Out:
#         Date  Global_active_power  Global_reactive_power  Voltage  \
# 0 2010-10-03                0.272                  0.000   246.80
# 1 2007-03-21                1.272                  0.000   238.52
# 2 2010-10-21                0.364                  0.106   245.20
# 3 2007-02-13                1.400                  0.102   242.97
# 4 2008-09-24                0.580                  0.330   240.25
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0               1.0             0.0             0.0             1.0
# 1               5.2             0.0             0.0            17.0
# 2               1.6             0.0             0.0             1.0
# 3               5.8             0.0             0.0            18.0
# 4               2.8             0.0             1.0             1.0

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   50000 non-null  datetime64[ns]
#  1   Global_active_power    49349 non-null  float64
#  2   Global_reactive_power  49349 non-null  float64
#  3   Voltage                49349 non-null  float64
#  4   Global_intensity       49349 non-null  float64
#  5   Sub_metering_1         49349 non-null  float64
#  6   Sub_metering_2         49349 non-null  float64
#  7   Sub_metering_3         49349 non-null  float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 3.1 MB

# %%
# Grouping Data on the basis of dates
df_sample = df_sample.groupby('Date').sum()

# %%
df_sample.reset_index(inplace=True)

# %%
df_sample
# Out:
#            Date  Global_active_power  Global_reactive_power   Voltage  \
# 0    2006-12-16               48.270                  1.466   3791.58
# 1    2006-12-17               67.822                  5.840   8424.08
# 2    2006-12-18               47.310                  2.940   7233.36
# 3    2006-12-19               34.682                  2.784   7753.55
# 4    2006-12-20               39.808                  2.356   7026.94
# ...         ...                  ...                    ...       ...
# 1437 2010-12-07               17.968                  5.326   6498.61
# 1438 2010-12-08                6.434                  2.040   5792.17
# 1439 2010-12-09               39.828                  4.960   7494.84
# 1440 2010-12-10               32.480                  3.220   6736.12
# 1441 2010-12-11               50.146                  4.420  10024.37
#
#       Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# ...

# %%
df_sample['Year'] = df_sample['Date'].dt.year
df_sample['Month'] = df_sample['Date'].dt.month

# %%
df_sample
# Out:
#            Date  Global_active_power  Global_reactive_power   Voltage  \
# 0    2006-12-16               48.270                  1.466   3791.58
# 1    2006-12-17               67.822                  5.840   8424.08
# 2    2006-12-18               47.310                  2.940   7233.36
# 3    2006-12-19               34.682                  2.784   7753.55
# 4    2006-12-20               39.808                  2.356   7026.94
# ...         ...                  ...                    ...       ...
# 1437 2010-12-07               17.968                  5.326   6498.61
# 1438 2010-12-08                6.434                  2.040   5792.17
# 1439 2010-12-09               39.828                  4.960   7494.84
# 1440 2010-12-10               32.480                  3.220   6736.12
# 1441 2010-12-11               50.146                  4.420  10024.37
#
#       Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  Year  \
# ...

# %%
df_sample.isna().sum()
# Out:
# Date                     0
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# Year                     0
# Month                    0
# dtype: int64

# %%
# We are removing year 2006 as it has loss data and it may create issue in our analysis
df_sample = df_sample[df_sample['Date']> '2006-12-31']

# %%
df_sample
# Out:
#            Date  Global_active_power  Global_reactive_power   Voltage  \
# 16   2007-01-01               84.864                  3.958  10567.28
# 17   2007-01-02               46.492                  2.546   7180.65
# 18   2007-01-03               15.518                  4.028  11327.05
# 19   2007-01-04               66.446                  5.694   8886.01
# 20   2007-01-05               47.150                  5.230   9161.27
# ...         ...                  ...                    ...       ...
# 1437 2010-12-07               17.968                  5.326   6498.61
# 1438 2010-12-08                6.434                  2.040   5792.17
# 1439 2010-12-09               39.828                  4.960   7494.84
# 1440 2010-12-10               32.480                  3.220   6736.12
# 1441 2010-12-11               50.146                  4.420  10024.37
#
#       Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  Year  \
# ...

# %%
df_sample.duplicated().sum()
# Out:
# 0

# %%
df_sample = df_sample.drop_duplicates()

# %%
df_sample.shape
# Out:
# (1426, 10)

# %%
df_sample.isnull().sum()
# Out:
# Date                     0
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# Year                     0
# Month                    0
# dtype: int64

# %% [markdown]
# Global active power column is the actual power consumption. So it is taken as per calculation i.e.
# Global active power * 1000/60 - (sub_metering_1 - sub_metering_2 - sub_metering_3). Please note
# that we did not measure sub-meterings 1, 2 and 3.

# %%
a = (df_sample['Global_active_power']*1000/60)
b = df_sample['Sub_metering_1'] + df_sample['Sub_metering_2']+ df_sample['Sub_metering_3']
df_sample['Power Consumption'] = a - b

# %%
df_sample.head()
# Out:
#          Date  Global_active_power  Global_reactive_power   Voltage  \
# 16 2007-01-01               84.864                  3.958  10567.28
# 17 2007-01-02               46.492                  2.546   7180.65
# 18 2007-01-03               15.518                  4.028  11327.05
# 19 2007-01-04               66.446                  5.694   8886.01
# 20 2007-01-05               47.150                  5.230   9161.27
#
#     Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  Year  \
# 16             351.4             0.0             9.0           157.0  2007
# 17             196.2            94.0             4.0           351.0  2007
# 18              66.2             0.0             9.0            35.0  2007
# 19             279.0            95.0            67.0           530.0  2007
# 20             208.0           114.0            21.0           216.0  2007
#
#     Month  Power Consumption
# 16      1        1248.400000
# 17      1         325.866667
# ...

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1426 entries, 16 to 1441
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   1426 non-null   datetime64[ns]
#  1   Global_active_power    1426 non-null   float64
#  2   Global_reactive_power  1426 non-null   float64
#  3   Voltage                1426 non-null   float64
#  4   Global_intensity       1426 non-null   float64
#  5   Sub_metering_1         1426 non-null   float64
#  6   Sub_metering_2         1426 non-null   float64
#  7   Sub_metering_3         1426 non-null   float64
#  8   Year                   1426 non-null   int64
#  9   Month                  1426 non-null   int64
#  10  Power Consumption      1426 non-null   float64
# dtypes: datetime64[ns](1), float64(8), int64(2)
# memory usage: 133.7 KB

# %%
df_sample['Sub_metering'] = df_sample['Sub_metering_1'] + df_sample['Sub_metering_2']+ df_sample['Sub_metering_3']

# %%
df_sample.head()
# Out:
#          Date  Global_active_power  Global_reactive_power   Voltage  \
# 16 2007-01-01               84.864                  3.958  10567.28
# 17 2007-01-02               46.492                  2.546   7180.65
# 18 2007-01-03               15.518                  4.028  11327.05
# 19 2007-01-04               66.446                  5.694   8886.01
# 20 2007-01-05               47.150                  5.230   9161.27
#
#     Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  Year  \
# 16             351.4             0.0             9.0           157.0  2007
# 17             196.2            94.0             4.0           351.0  2007
# 18              66.2             0.0             9.0            35.0  2007
# 19             279.0            95.0            67.0           530.0  2007
# 20             208.0           114.0            21.0           216.0  2007
#
#     Month  Power Consumption  Sub_metering
# 16      1        1248.400000         166.0
# ...

# %%
df_sample_copy = df_sample.copy()

# %%
df_sample_copy
# Out:
#            Date  Global_active_power  Global_reactive_power   Voltage  \
# 16   2007-01-01               84.864                  3.958  10567.28
# 17   2007-01-02               46.492                  2.546   7180.65
# 18   2007-01-03               15.518                  4.028  11327.05
# 19   2007-01-04               66.446                  5.694   8886.01
# 20   2007-01-05               47.150                  5.230   9161.27
# ...         ...                  ...                    ...       ...
# 1437 2010-12-07               17.968                  5.326   6498.61
# 1438 2010-12-08                6.434                  2.040   5792.17
# 1439 2010-12-09               39.828                  4.960   7494.84
# 1440 2010-12-10               32.480                  3.220   6736.12
# 1441 2010-12-11               50.146                  4.420  10024.37
#
#       Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  Year  \
# ...

# %%
df_sample = df_sample.drop(['Sub_metering_1','Sub_metering_2','Sub_metering_3'], axis =1)

# %%
df_sample.head()
# Out:
#          Date  Global_active_power  Global_reactive_power   Voltage  \
# 16 2007-01-01               84.864                  3.958  10567.28
# 17 2007-01-02               46.492                  2.546   7180.65
# 18 2007-01-03               15.518                  4.028  11327.05
# 19 2007-01-04               66.446                  5.694   8886.01
# 20 2007-01-05               47.150                  5.230   9161.27
#
#     Global_intensity  Year  Month  Power Consumption  Sub_metering
# 16             351.4  2007      1        1248.400000         166.0
# 17             196.2  2007      1         325.866667         449.0
# 18              66.2  2007      1         214.633333          44.0
# 19             279.0  2007      1         415.433333         692.0
# 20             208.0  2007      1         434.833333         351.0

# %%
df_sample.describe().T
# Out:
#                         count         mean          std     min          25%  \
# Global_active_power    1426.0    37.316562    17.367554     0.0    25.388500
# Global_reactive_power  1426.0     4.230554     1.548677     0.0     3.197000
# Voltage                1426.0  8249.195035  1632.331166     0.0  7271.195000
# Global_intensity       1426.0   158.229032    72.360358     0.0   109.200000
# Year                   1426.0  2008.462833     1.106450  2007.0  2007.000000
# Month                  1426.0     6.437588     3.410299     1.0     3.000000
# Power Consumption      1426.0   318.163604   167.426732     0.0   206.433333
# Sub_metering           1426.0   303.779102   159.250471     0.0   187.000000
#
#                             50%          75%           max
# Global_active_power      35.510    47.022000    121.996000
# Global_reactive_power     4.004     5.089500     11.168000
# Voltage                8248.655  9226.597500  12548.240000
# ...

# %%
df_sample.corr()
# Out:
#                        Global_active_power  Global_reactive_power   Voltage  \
# Global_active_power               1.000000               0.288240  0.458866
# Global_reactive_power             0.288240               1.000000  0.506291
# Voltage                           0.458866               0.506291  1.000000
# Global_intensity                  0.999251               0.308735  0.465069
# Year                             -0.075361               0.051989 -0.069305
# Month                            -0.018924               0.021244 -0.037662
# Power Consumption                 0.891992               0.159699  0.411378
# Sub_metering                      0.879846               0.356017  0.401552
#
#                        Global_intensity      Year     Month  \
# Global_active_power            0.999251 -0.075361 -0.018924
# Global_reactive_power          0.308735  0.051989  0.021244
# Voltage                        0.465069 -0.069305 -0.037662
# ...

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(df_sample.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df_sample['Global_intensity'],df_sample['Global_active_power'])

# %%
df_sample.describe().T
# Out:
#                         count         mean          std     min          25%  \
# Global_active_power    1426.0    37.316562    17.367554     0.0    25.388500
# Global_reactive_power  1426.0     4.230554     1.548677     0.0     3.197000
# Voltage                1426.0  8249.195035  1632.331166     0.0  7271.195000
# Global_intensity       1426.0   158.229032    72.360358     0.0   109.200000
# Year                   1426.0  2008.462833     1.106450  2007.0  2007.000000
# Month                  1426.0     6.437588     3.410299     1.0     3.000000
# Power Consumption      1426.0   318.163604   167.426732     0.0   206.433333
# Sub_metering           1426.0   303.779102   159.250471     0.0   187.000000
#
#                             50%          75%           max
# Global_active_power      35.510    47.022000    121.996000
# Global_reactive_power     4.004     5.089500     11.168000
# Voltage                8248.655  9226.597500  12548.240000
# ...

# %%
df_sample.columns
# Out:
# Index(['Date', 'Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Global_intensity', 'Year', 'Month', 'Power Consumption',
#        'Sub_metering'],
#       dtype='object')

# %%
# Creating a list for all columns to analyze it graphically
columns = list(df_sample.columns)
df_graph_col =columns[1:9]
df_graph_col
# Out:
# ['Global_active_power',
#  'Global_reactive_power',
#  'Voltage',
#  'Global_intensity',
#  'Year',
#  'Month',
#  'Power Consumption',
#  'Sub_metering']

# %%
df_sample.head()
# Out:
#          Date  Global_active_power  Global_reactive_power   Voltage  \
# 16 2007-01-01               84.864                  3.958  10567.28
# 17 2007-01-02               46.492                  2.546   7180.65
# 18 2007-01-03               15.518                  4.028  11327.05
# 19 2007-01-04               66.446                  5.694   8886.01
# 20 2007-01-05               47.150                  5.230   9161.27
#
#     Global_intensity  Year  Month  Power Consumption  Sub_metering
# 16             351.4  2007      1        1248.400000         166.0
# 17             196.2  2007      1         325.866667         449.0
# 18              66.2  2007      1         214.633333          44.0
# 19             279.0  2007      1         415.433333         692.0
# 20             208.0  2007      1         434.833333         351.0

# %%
# Grouping by year of consumption
df_year = pd.DataFrame(df_sample.groupby('Year')['Power Consumption'].sum())

# %%
df_year
# Out:
#       Power Consumption
# Year
# 2007      128324.100000
# 2008      119432.233333
# 2009      113986.600000
# 2010       91958.366667

# %%
df_year.describe().T
# Out:
#                    count        mean           std           min  \
# Power Consumption    4.0  113425.325  15483.343458  91958.366667
#
#                              25%            50%       75%       max
# Power Consumption  108479.541667  116709.416667  121655.2  128324.1

# %%
df_year.plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
import cufflinks as cf
import plotly
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_year.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df_year.iplot()
# Out:
# <div>                            <div id="e57a8cf0-b9d7-47fb-a922-1d9a6619fc38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#Grouping data by month
df_year_month = pd.DataFrame(df_sample.groupby(['Year','Month']).sum()['Power Consumption'])
df_year_month.reset_index(inplace=True)

# %%
df_year_month
# Out:
#     Year  Month  Power Consumption
# 0   2007      1       15345.000000
# 1   2007      2       11247.300000
# 2   2007      3       12253.800000
# 3   2007      4        8097.200000
# 4   2007      5       10056.433333
# 5   2007      6        7135.133333
# 6   2007      7        7749.900000
# 7   2007      8        8694.700000
# 8   2007      9        8337.966667
# 9   2007     10       10871.733333
# 10  2007     11       14261.800000
# 11  2007     12       14273.133333
# 12  2008      1       13746.300000
# 13  2008      2        9774.766667
# 14  2008      3       10660.333333
# 15  2008      4        9170.333333
# 16  2008      5        9141.933333
# 17  2008      6        8287.833333
# 18  2008      7        7201.366667
# 19  2008      8        5141.400000
# 20  2008      9        8752.033333
# 21  2008     10       11048.900000
# 22  2008     11       13998.466667
# 23  2008     12       12508.566667
# 24  2009      1       12558.266667
# 25  2009      2       10040.033333
# ...

# %%
df_year_month.describe().T
# Out:
#                    count         mean          std          min       25%  \
# Year                48.0  2008.500000     1.129865  2007.000000  2007.750
# Month               48.0     6.500000     3.488583     1.000000     3.750
# Power Consumption   48.0  9452.110417  2547.211163  2792.666667  7961.925
#
#                            50%           75%      max
# Year               2008.500000   2009.250000   2010.0
# Month                 6.500000      9.250000     12.0
# Power Consumption  8946.983333  10856.908333  15345.0

# %%
df_month_1 = pd.DataFrame(df_year_month.groupby('Year')['Power Consumption'].max())
df_month_1.reset_index(inplace=True)

# %%
df_month_1
# Out:
#    Year  Power Consumption
# 0  2007       15345.000000
# 1  2008       13998.466667
# 2  2009       12558.266667
# 3  2010       10380.466667

# %% [markdown]
# # Ploting graph for visual analysis

# %%
plt.figure(figsize=[15,15])
for i in range(df_sample.shape[1]-1):
    plt.subplot(3,3,i+1)
    sns.kdeplot(df_sample.iloc[:,i])

# %%
# Box plot to detect outliers in dataset
plt.figure(figsize=[15,15])
for i,col in enumerate(df_graph_col):
    plt.subplot(3,3,i+1)
    sns.boxplot(df_sample[col])
# Out:
# C:\Users\rupto\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# C:\Users\rupto\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# C:\Users\rupto\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# ...

# %%
# Function to identify outlier
def outlier_thresholds(dataframe,variable):
    quartile1 = dataframe[variable].quantile(0.25)
    quartile3 = dataframe[variable].quantile(0.75)
    iqr = quartile3 - quartile1
    upper_limit = quartile3 + 1.5 * iqr
    lower_limit = quartile1 - 1.5 * iqr
    return lower_limit, upper_limit

# Function to remove outlier
def replace_with_thresholds(dataframe,columns):
    lower_limit, upper_limit = outlier_thresholds(dataframe,col)
    dataframe.loc[(dataframe[col] < lower_limit), col] = lower_limit
    dataframe.loc[(dataframe[col] > upper_limit), col] = upper_limit

# %%
df_sample
# Out:
#            Date  Global_active_power  Global_reactive_power   Voltage  \
# 16   2007-01-01               84.864                  3.958  10567.28
# 17   2007-01-02               46.492                  2.546   7180.65
# 18   2007-01-03               15.518                  4.028  11327.05
# 19   2007-01-04               66.446                  5.694   8886.01
# 20   2007-01-05               47.150                  5.230   9161.27
# ...         ...                  ...                    ...       ...
# 1437 2010-12-07               17.968                  5.326   6498.61
# 1438 2010-12-08                6.434                  2.040   5792.17
# 1439 2010-12-09               39.828                  4.960   7494.84
# 1440 2010-12-10               32.480                  3.220   6736.12
# 1441 2010-12-11               50.146                  4.420  10024.37
#
#       Global_intensity  Year  Month  Power Consumption  Sub_metering
# ...

# %%
replace_with_thresholds(df_sample,columns)

# %%
#Again checking for outliers
plt.figure(figsize=[15,15])
for i,col in enumerate(df_graph_col):
    plt.subplot(3,3,i+1)
    sns.boxplot(df_sample[col])
# Out:
# C:\Users\rupto\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# C:\Users\rupto\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# C:\Users\rupto\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# ...

# %%
columns
# Out:
# ['Date',
#  'Global_active_power',
#  'Global_reactive_power',
#  'Voltage',
#  'Global_intensity',
#  'Year',
#  'Month',
#  'Power Consumption',
#  'Sub_metering']

# %%
df_graph_col
# Out:
# ['Global_active_power',
#  'Global_reactive_power',
#  'Voltage',
#  'Global_intensity',
#  'Year',
#  'Month',
#  'Power Consumption',
#  'Sub_metering']

# %%
plt.figure(figsize=(15,15))
for i in range(len(df_graph_col)):
    plt.subplot(3,3,i+1)
    sns.distplot(df_sample[df_graph_col[i]])
# Out:
# C:\Users\rupto\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\rupto\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\rupto\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# ...

# %%
df_sample_copy.head()
# Out:
#          Date  Global_active_power  Global_reactive_power   Voltage  \
# 16 2007-01-01               84.864                  3.958  10567.28
# 17 2007-01-02               46.492                  2.546   7180.65
# 18 2007-01-03               15.518                  4.028  11327.05
# 19 2007-01-04               66.446                  5.694   8886.01
# 20 2007-01-05               47.150                  5.230   9161.27
#
#     Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  Year  \
# 16             351.4             0.0             9.0           157.0  2007
# 17             196.2            94.0             4.0           351.0  2007
# 18              66.2             0.0             9.0            35.0  2007
# 19             279.0            95.0            67.0           530.0  2007
# 20             208.0           114.0            21.0           216.0  2007
#
#     Month  Power Consumption  Sub_metering
# 16      1        1248.400000         166.0
# ...

# %% [markdown]
# # Grouping data

# %%
df_sample_copy.groupby(['Year','Month'])['Sub_metering_1','Sub_metering_2','Sub_metering_3'].sum()
# Out:
# C:\Users\rupto\AppData\Local\Temp/ipykernel_83588/4144085989.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#             Sub_metering_1  Sub_metering_2  Sub_metering_3
# Year Month
# 2007 1              1811.0          1884.0          8169.0
#      2               949.0          1682.0          5711.0
#      3              1553.0          2535.0          6984.0
#      4              1145.0          1475.0          4797.0
#      5              1684.0          1817.0          5614.0
#      6              1480.0          1407.0          4631.0
#      7               874.0          1772.0          5086.0
#      8              1189.0          1781.0          5835.0
#      9              1158.0          1770.0          5830.0
#      10             1114.0          1856.0          6064.0
#      11             1456.0          1788.0          7820.0
# ...

# %%
df_sample_copy.groupby(['Year'])['Sub_metering_1','Sub_metering_2','Sub_metering_3'].sum().plot(kind='bar')
# Out:
# C:\Users\rupto\AppData\Local\Temp/ipykernel_83588/3000100586.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <AxesSubplot:xlabel='Year'>

# %%
df_sample_copy.groupby(['Month'])['Sub_metering_1','Sub_metering_2','Sub_metering_3'].sum().plot(kind='bar')
# Out:
# C:\Users\rupto\AppData\Local\Temp/ipykernel_83588/887332589.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# # Model Building

# %%
df_sample.head()
# Out:
#          Date  Global_active_power  Global_reactive_power   Voltage  \
# 16 2007-01-01               84.864                  3.958  10567.28
# 17 2007-01-02               46.492                  2.546   7180.65
# 18 2007-01-03               15.518                  4.028  11327.05
# 19 2007-01-04               66.446                  5.694   8886.01
# 20 2007-01-05               47.150                  5.230   9161.27
#
#     Global_intensity  Year  Month  Power Consumption  Sub_metering
# 16             351.4  2007      1        1248.400000         166.0
# 17             196.2  2007      1         325.866667         449.0
# 18              66.2  2007      1         214.633333          44.0
# 19             279.0  2007      1         415.433333         692.0
# 20             208.0  2007      1         434.833333         351.0

# %%
#Selecting dependent and Independent features
X = df_sample.iloc[:,[1,2,3,8]] #Independent feature
y = df_sample.iloc[:,7] #Dependent feature

# %%
X.head()
# Out:
#     Global_active_power  Global_reactive_power   Voltage  Sub_metering
# 16               84.864                  3.958  10567.28         166.0
# 17               46.492                  2.546   7180.65         449.0
# 18               15.518                  4.028  11327.05          44.0
# 19               66.446                  5.694   8886.01         692.0
# 20               47.150                  5.230   9161.27         351.0

# %%
y.head()
# Out:
# 16    1248.400000
# 17     325.866667
# 18     214.633333
# 19     415.433333
# 20     434.833333
# Name: Power Consumption, dtype: float64

# %%
sns.pairplot(X)

# %%
sns.regplot(x=df_sample['Sub_metering'], y=df_sample['Power Consumption'],data=df_sample)
# Out:
# <AxesSubplot:xlabel='Sub_metering', ylabel='Power Consumption'>

# %%
# Splitting training data and testing data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=7,test_size=0.33)

# %%
# Preprocessing
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train.head()
# Out:
#      Global_active_power  Global_reactive_power  Voltage  Sub_metering
# 398               42.752                  2.224  7424.20         327.0
# 183               43.328                  7.186  8159.26         442.0
# 88                22.304                  2.424  6524.15         190.0
# 86                37.288                  3.840  7948.59         219.0
# 667               32.608                  2.010  6973.84         222.0

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test= scaler.transform(X_test)

# %% [markdown]
# # Storing the preprocessed model as file

# %%
#Pickling
preprocess_model = [X_train, y_train, X_test, y_test]
import pickle
pickle.dump(preprocess_model, open('preprocess_model.pkl','wb'))

# %%
#Load our model from pickle file
preprocess_model = pickle.load(open('preprocess_model.pkl','rb'))

# %% [markdown]
# # Storing the preprocessed model data into MongoDB

# %%
database_df = pd.DataFrame([X_train.T[0],X_train.T[1],X_train.T[2],X_train.T[3],y_train]).T
database_df.columns = ['Global_active_power','Global_reactive_power','Vlotage','Sub_metering','power_consumption']

# %%
database_df.head()
# Out:
#    Global_active_power  Global_reactive_power   Vlotage  Sub_metering  \
# 0             0.356291              -1.294884 -0.494181      0.191603
# 1             0.390466               1.980993 -0.040668      0.948353
# 2            -0.856933              -1.162845 -1.049488     -0.709917
# 3             0.032100              -0.228012 -0.170646     -0.519085
# 4            -0.245575              -1.436165 -0.772041     -0.499343
#
#    power_consumption
# 0         385.533333
# 1         280.133333
# 2         181.733333
# 3         402.466667
# 4         321.466667

# %%
l=[]
for i , row in database_df.iterrows():
    l.append(dict(row))

# %%
import pymongo
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://ineuron:ineuron12@cluster0.coepdpz.mongodb.net/?retryWrites=true&w=majority")

# %%
db = client['preprocess_data']
collections = db['Table1']
#collections.insert_many(l)

# %%
# Restoring Pickeled data from Pickel file into variables
X_train = preprocess_model[0]
y_train = preprocess_model[1]
X_test = preprocess_model[2]
y_test = preprocess_model[3]

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [ 277.80633123   -1.63113054    1.55918546 -152.5156433 ]

# %%
print(regression.intercept_)
# Out:
# 313.40890052356025

# %%
# Prediction for test data
reg_pred = regression.predict(X_test)

# %%
reg_pred
# Out:
# array([ 186.95219882,  188.27435154,  290.58336866,  280.96477882,
#         204.31423281,  174.44012438,  167.97412589,  565.82145484,
#         337.79437609,   99.34952855,  467.15689313,  243.32241865,
#         549.78012221,  304.10267421,  206.47650714,  348.33101372,
#         336.42439454,  185.80188028,  159.25398576,  427.8232818 ,
#         314.42480083,  233.03484303,  600.53859816,  424.31156196,
#         178.41294647,  155.94862981,  329.24713633,  374.31289933,
#         228.44105098,  282.60363764,  249.59877523,  321.31489528,
#         415.59743283,  406.50275607,  550.91799248,  190.56431379,
#         119.16595243,  276.9871334 ,  441.1072847 ,  210.87080462,
#         445.07707024,  293.21888345,    3.26973848,  383.64487036,
#         294.96078226,  560.30561386,  253.97427922,  188.93086839,
#         339.03006677,  574.34673461,  180.95214897,  417.14249089,
#         648.21921705,  368.5195496 ,  254.33361154,  376.08484022,
# ...

# %%
from sklearn.metrics import r2_score
# R Square Score
linear_r2 = r2_score(y_test,reg_pred)
print(linear_r2)
# Out:
# 0.982583866074189

# %%
# Adjusted R Square
adjusted_linear_r2 = 1 - (1 -  linear_r2) * (len(y_test) - 1)/(len(y_test) - X_test.shape[1] - 1)
print(adjusted_linear_r2)
# Out:
# 0.9824343713623794

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()

# %%
ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
ridge_pred = ridge.predict(X_test)

# %%
ridge_pred
# Out:
# array([ 187.98621843,  188.62554934,  290.56212379,  281.57458665,
#         205.24628099,  176.21064269,  168.32114606,  564.57909649,
#         336.60764903,   99.66254144,  466.32773815,  243.89313678,
#         549.01858496,  304.80708981,  208.03532231,  348.87476454,
#         337.97194019,  186.90944028,  160.42745282,  426.25555021,
#         313.6704891 ,  233.15638659,  600.69165674,  424.62147255,
#         180.54673189,  156.65376475,  329.39961769,  375.66625437,
#         229.07147074,  283.1463843 ,  249.54778607,  322.94290844,
#         415.08964195,  404.73981302,  551.32533236,  190.61516657,
#         119.42856222,  278.519412  ,  439.9164163 ,  213.10005743,
#         445.02624143,  293.52370231,    3.06473766,  384.46922404,
#         293.81344091,  559.07862302,  253.70022188,  189.35907527,
#         340.56078313,  573.36651124,  181.71810626,  416.80529742,
#         648.42184231,  369.8750292 ,  255.59439412,  376.35548806,
# ...

# %%
# R Square score
ridge_r2 = r2_score(y_test,ridge_pred)
print(ridge_r2)
# Out:
# 0.9826764383512921

# %%
# Adjusted R Square
adjusted_ridge_r2 = 1 - (1 -  ridge_r2) * (len(y_test) - 1)/(len(y_test) - X_test.shape[1] - 1)
print(adjusted_ridge_r2)
# Out:
# 0.9825277382513032

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()

# %%
lasso.fit(X_train,y_train)
# Out:
# Lasso()

# %%
lasso_pred = lasso.predict(X_test)

# %%
lasso_pred
# Out:
# array([ 196.12068071,  185.73622705,  293.54004315,  283.83007838,
#         209.55652695,  179.31723849,  171.85053672,  561.69852396,
#         330.40436214,  101.23145695,  464.066133  ,  245.96485469,
#         547.18119253,  306.718596  ,  215.70366958,  351.83560161,
#         341.21973072,  191.46445904,  162.4671874 ,  422.52178051,
#         308.75960999,  237.28500133,  602.16568294,  427.17474084,
#         193.01076868,  159.3003274 ,  329.39999645,  379.92652145,
#         231.49467888,  284.09104492,  247.96434923,  325.14091543,
#         413.01709143,  399.08850485,  550.01386233,  191.75297762,
#         119.57028054,  283.22634581,  434.34808217,  221.98715556,
#         447.38588231,  291.25020698,    7.08587943,  387.45706633,
#         293.39487429,  551.76152804,  253.11995865,  194.6740168 ,
#         344.87748379,  570.30088312,  181.52334868,  415.28687452,
#         647.50318747,  371.98294885,  257.72638078,  374.4465266 ,
# ...

# %%
# R Square score
lasso_r2 = r2_score(y_test,lasso_pred)
print(lasso_r2)
# Out:
# 0.9825852847428086

# %%
# Adjusted R Square
adjusted_lasso_r2 = 1 - (1 -  lasso_r2) * (len(y_test) - 1)/(len(y_test) - X_test.shape[1] - 1)
print(adjusted_lasso_r2)
# Out:
# 0.9824358022084121

# %% [markdown]
# # ElasticNet

# %%
from sklearn.linear_model import ElasticNet
elastic = ElasticNet()

# %%
elastic.fit(X_train,y_train)
# Out:
# ElasticNet()

# %%
elastic_pred = elastic.predict(X_test)

# %%
elastic_pred
# Out:
# array([293.99555577, 227.91483376, 301.69054285, 330.17775392,
#        294.6003944 , 319.88845547, 221.05664304, 438.87137014,
#        240.62919007, 163.68715655, 374.33319457, 299.78294383,
#        457.20355932, 350.99849874, 346.55730855, 371.5528508 ,
#        430.95977608, 297.09092181, 272.21972045, 292.13085218,
#        252.53410894, 284.57469674, 556.84529066, 435.87644627,
#        379.76413785, 232.84907184, 335.5165448 , 451.00469433,
#        281.33156403, 321.73198996, 249.76229213, 424.20377212,
#        355.02141498, 267.39306915, 530.02507122, 211.04967464,
#        176.15203053, 401.18170736, 322.96274509, 399.77457744,
#        431.15283959, 307.2939585 ,  31.57850452, 430.69647792,
#        226.09427725, 420.3909446 , 245.23420951, 255.96669839,
#        437.93447072, 458.70729334, 251.53623278, 375.68756607,
#        601.94176369, 441.52735591, 349.02156673, 370.68836135,
#        544.75493784, 303.31445477, 219.81662358, 300.11290774,
# ...

# %%
#R Square score
elastic_r2 = r2_score(y_test,elastic_pred)
print(elastic_r2)
# Out:
# 0.7041044398550167

# %%
#Adjusted R Square
adjusted_elastic_r2 = 1 - (1 -  elastic_r2) * (len(y_test) - 1)/(len(y_test) - X_test.shape[1] - 1)
print(adjusted_elastic_r2)
# Out:
# 0.7015645638022701

# %% [markdown]
# # Support Vector Regression (SVR)

# %%
from sklearn.svm import SVR
svr = SVR()

# %%
svr.fit(X_train,y_train)
# Out:
# SVR()

# %%
svr_pred = svr.predict(X_test)

# %%
svr_pred
# Out:
# array([284.3273067 , 243.20176097, 282.14182193, 312.50843009,
#        279.40528655, 304.93320533, 225.7297275 , 375.08601657,
#        244.52903719, 202.1990722 , 330.19625907, 282.18637434,
#        379.21641704, 329.98876469, 314.08113673, 310.34822351,
#        352.24866887, 283.12053183, 264.84209356, 271.26961001,
#        246.34395228, 286.7990507 , 330.9500328 , 351.83141221,
#        302.62981983, 221.97532433, 318.04241492, 342.22291166,
#        266.72389227, 305.38595397, 238.71614209, 356.34577806,
#        328.25101992, 248.88534125, 351.19369852, 227.00768061,
#        214.38802087, 324.7325668 , 296.70089388, 319.62833806,
#        345.15369181, 291.57159471, 281.93370452, 363.01776063,
#        230.1562319 , 360.40548844, 228.61543713, 258.86003816,
#        356.37129177, 384.93215621, 243.42749997, 349.76267616,
#        322.36254142, 351.54466676, 330.35294289, 337.87789187,
#        313.73096051, 287.42444784, 223.42500653, 287.54081448,
# ...

# %%
#R Square score
svr_r2 = r2_score(y_test,svr_pred)
print(svr_r2)
# Out:
# 0.25178222626377267

# %%
#Adjusted R Square
adjusted_svr_r2 = 1 - (1 -  svr_r2) * (len(y_test) - 1)/(len(y_test) - X_test.shape[1] - 1)
print(adjusted_svr_r2)
# Out:
# 0.2453597561029467

# %% [markdown]
# # Decission Tree Regressor (DTR)

# %%
# import the regressor
from sklearn.tree import DecisionTreeRegressor 
  
# create a regressor object
dectree = DecisionTreeRegressor(random_state = 0) 
  
# fit the regressor with X and Y data
dectree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
dectreeReg_pred = dectree.predict(X_test)

# %%
dectreeReg_pred
# Out:
# array([ 224.36666667,  167.73333333,  307.16666667,  275.83333333,
#         223.13333333,  152.83333333,  185.63333333,  544.76666667,
#         303.1       ,  137.9       ,  438.26666667,  218.83333333,
#         562.6       ,  315.26666667,  281.6       ,  350.26666667,
#         352.96666667,  209.2       ,  170.66666667,  397.4       ,
#         315.26666667,  254.33333333,  537.1       ,  418.43333333,
#         278.6       ,  161.36666667,  344.46666667,  443.96666667,
#         217.56666667,  290.9       ,  245.6       ,  349.93333333,
#         399.2       ,  430.2       ,  557.06666667,  180.96666667,
#         137.9       ,  299.8       ,  429.9       ,  261.3       ,
#         418.43333333,  275.83333333,    0.        ,  418.43333333,
#         278.06666667,  528.06666667,  256.1       ,  207.03333333,
#         348.76666667,  562.6       ,  190.2       ,  402.5       ,
#         537.1       ,  390.83333333,  268.93333333,  387.6       ,
# ...

# %%
#R Square score
dectree_r2 = r2_score(y_test,dectreeReg_pred)
print(dectree_r2)
# Out:
# 0.9543133114656586

# %%
#Adjusted R Square
adjusted_dectree_r2 = 1 - (1 -  dectree_r2) * (len(y_test) - 1)/(len(y_test) - X_test.shape[1] - 1)
print(adjusted_dectree_r2)
# Out:
# 0.9539211510490547

# %% [markdown]
# # Applying Hyperparameter Tuning

# %%
params = {'kernel':['linear','poly','sigmoid','rbf']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(estimator=svr,param_grid=params,cv=10,n_jobs=-1)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=SVR(), n_jobs=-1,
#              param_grid={'kernel': ['linear', 'poly', 'sigmoid', 'rbf']})

# %%
grid.best_params_
# Out:
# {'kernel': 'linear'}

# %%
grid.best_score_
# Out:
# 0.9438197361790566

# %%
results = {'models':['linear','ridge','lasso','elastic','svr','decission tree reg'],
          'r_square':[linear_r2,ridge_r2,lasso_r2,elastic_r2,svr_r2,dectree_r2],
          'adjusted_r_square':[adjusted_linear_r2,adjusted_ridge_r2,adjusted_lasso_r2,adjusted_elastic_r2,adjusted_svr_r2,adjusted_dectree_r2]}

# %%
df_score = pd.DataFrame(results)

# %%
df_score
# Out:
#                models  r_square  adjusted_r_square
# 0              linear  0.982584           0.982434
# 1               ridge  0.982676           0.982528
# 2               lasso  0.982585           0.982436
# 3             elastic  0.704104           0.701565
# 4                 svr  0.251782           0.245360
# 5  decission tree reg  0.954313           0.953921

# %%
#1. Linear relation netween input and output feature
plt.figure(figsize=[15,15])
for i in range(X_test.shape[1]):
    plt.subplot(3,3,i+1)
    plt.xlabel('X_train')
    plt.ylabel('y_train')
    plt.scatter(X_train.T[i],y_train)

# %%
#2. No Multicolinearlty
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = []

for i in range(X_train.shape[1]):
    vif.append(variance_inflation_factor(X_train,i))

# %%
vif
# Out:
# [4.809200137084401, 1.4052614836311816, 1.5912331068697334, 4.590462637106467]

# %%
#3. Residuals should be normally distributed 
residuals = y_test - reg_pred

# %%
sns.displot(residuals, kind='kde')

# %%
#4. Homoscedasticity - Spread of residuals in graph should be equal
plt.scatter(reg_pred,residuals)

# %%
#5. No Auto-correlation of errors - No auto-correleation in plot of residuals
plt.plot(residuals)
